# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, roc_curve, precision_recall_curve, auc, make_scorer, recall_score, accuracy_score, precision_score, confusion_matrix

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
file_path = '/content/drive/MyDrive/HSM564/'

# %%
# Load the dataset
obesity = pd.read_csv(file_path + 'obesity_data.csv')

# Display the first few rows
obesity.head()
# Out:
#    Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0   56    Male  173.575262  71.982051  23.891783                      4
# 1   69    Male  164.127306  89.959256  33.395209                      2
# 2   46  Female  168.072202  72.930629  25.817737                      4
# 3   32    Male  168.459633  84.886912  29.912247                      3
# 4   60    Male  183.568568  69.038945  20.487903                      3
#
#   ObesityCategory
# 0   Normal weight
# 1           Obese
# 2      Overweight
# 3      Overweight
# 4   Normal weight

# %%
obesity.shape
# Out:
# (1000, 7)

# %%
import sys
# append the function .py file file path to the system path
# function.py is uploaded to /content/drive/MyDrive/Functions folder
if '/content/drive/MyDrive/HSM564' not in sys.path:
  sys.path.append('/content/drive/MyDrive/HSM564')

# %%
import function as fun

# %%
# check the data types
obesity.dtypes
# Out:
# Age                        int64
# Gender                    object
# Height                   float64
# Weight                   float64
# BMI                      float64
# PhysicalActivityLevel      int64
# ObesityCategory           object
# dtype: object

# %%
fun.metadata(obesity)
# Out:
#              column_name datatype  missing_percent  unique        mean  \
# 0                    Age    int64              0.0      62   49.857000
# 1                 Gender   object              0.0       2         NaN
# 2                 Height  float64              0.0    1000  170.052417
# 3                 Weight  float64              0.0    1000   71.205769
# 4                    BMI  float64              0.0    1000   24.888317
# 5  PhysicalActivityLevel    int64              0.0       4         NaN
# 6        ObesityCategory   object              0.0       4         NaN
#
#          std         min         25%         50%         75%         max
# 0  18.114267   18.000000   35.000000   50.000000   66.000000   79.000000
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2  10.309971  136.115719  163.514205  169.801665  177.353596  201.419670
# 3  15.509849   26.065730   61.129629   71.929072   81.133746  118.907366
# 4   6.193912    8.470572   20.918068   24.698647   28.732132   50.791898
# 5        NaN         NaN         NaN         NaN         NaN         NaN
# 6        NaN         NaN         NaN         NaN         NaN         NaN

# %%
# Using pandas get_dummies
obesity_encoded = pd.get_dummies(obesity, columns=['Gender', 'PhysicalActivityLevel', 'ObesityCategory']).astype(int)
obesity_encoded.head()
# Out:
#    Age  Height  Weight  BMI  Gender_Female  Gender_Male  \
# 0   56     173      71   23              0            1
# 1   69     164      89   33              0            1
# 2   46     168      72   25              1            0
# 3   32     168      84   29              0            1
# 4   60     183      69   20              0            1
#
#    PhysicalActivityLevel_1  PhysicalActivityLevel_2  PhysicalActivityLevel_3  \
# 0                        0                        0                        0
# 1                        0                        1                        0
# 2                        0                        0                        0
# 3                        0                        0                        1
# 4                        0                        0                        1
#
#    PhysicalActivityLevel_4  ObesityCategory_Normal weight  \
# 0                        1                              1
# 1                        0                              0
# 2                        1                              0
# 3                        0                              0
# 4                        0                              1
#
#    ObesityCategory_Obese  ObesityCategory_Overweight  \
# 0                      0                           0
# 1                      1                           0
# 2                      0                           1
# 3                      0                           1
# 4                      0                           0
#
#    ObesityCategory_Underweight
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
fun.metadata(obesity_encoded)
# Out:
#                       column_name datatype  missing_percent  unique     mean  \
# 0                             Age    int64              0.0      62   49.857
# 1                          Height    int64              0.0      60  169.549
# 2                          Weight    int64              0.0      83   70.685
# 3                             BMI    int64              0.0      39   24.384
# 4                   Gender_Female    int64              0.0       2      NaN
# 5                     Gender_Male    int64              0.0       2      NaN
# 6         PhysicalActivityLevel_1    int64              0.0       2      NaN
# 7         PhysicalActivityLevel_2    int64              0.0       2      NaN
# 8         PhysicalActivityLevel_3    int64              0.0       2      NaN
# 9         PhysicalActivityLevel_4    int64              0.0       2      NaN
# 10  ObesityCategory_Normal weight    int64              0.0       2      NaN
# 11          ObesityCategory_Obese    int64              0.0       2      NaN
# 12     ObesityCategory_Overweight    int64              0.0       2      NaN
# 13    ObesityCategory_Underweight    int64              0.0       2      NaN
#
#           std    min    25%    50%    75%    max
# 0   18.114267   18.0   35.0   50.0   66.0   79.0
# 1   10.316202  136.0  163.0  169.0  177.0  201.0
# 2   15.507490   26.0   61.0   71.0   81.0  118.0
# 3    6.204437    8.0   20.0   24.0   28.0   50.0
# 4         NaN    NaN    NaN    NaN    NaN    NaN
# 5         NaN    NaN    NaN    NaN    NaN    NaN
# 6         NaN    NaN    NaN    NaN    NaN    NaN
# 7         NaN    NaN    NaN    NaN    NaN    NaN
# 8         NaN    NaN    NaN    NaN    NaN    NaN
# 9         NaN    NaN    NaN    NaN    NaN    NaN
# 10        NaN    NaN    NaN    NaN    NaN    NaN
# 11        NaN    NaN    NaN    NaN    NaN    NaN
# 12        NaN    NaN    NaN    NaN    NaN    NaN
# 13        NaN    NaN    NaN    NaN    NaN    NaN

# %%
# Compute the correlation matrix
correlation_matrix_obesity = obesity_encoded.corr()

# Display the correlation matrix
print(correlation_matrix_obesity)
# Out:
#                                     Age    Height    Weight       BMI  \
# Age                            1.000000  0.019405 -0.061498 -0.059791
# Height                         0.019405  1.000000  0.013915 -0.478429
# Weight                        -0.061498  0.013915  1.000000  0.860183
# BMI                           -0.059791 -0.478429  0.860183  1.000000
# Gender_Female                 -0.036248 -0.016286  0.034134  0.037074
# Gender_Male                    0.036248  0.016286 -0.034134 -0.037074
# PhysicalActivityLevel_1        0.030458 -0.000730 -0.074387 -0.062682
# PhysicalActivityLevel_2        0.029113 -0.036791  0.048142  0.063622
# PhysicalActivityLevel_3       -0.089913  0.000001 -0.036513 -0.035488
# PhysicalActivityLevel_4        0.031146  0.036928  0.061351  0.033697
# ObesityCategory_Normal weight  0.039223  0.200828 -0.270202 -0.357668
# ObesityCategory_Obese         -0.022719 -0.361165  0.562661  0.703398
# ObesityCategory_Overweight    -0.059323 -0.083354  0.278689  0.253430
# ObesityCategory_Underweight    0.048666  0.237004 -0.621993 -0.626422
#
#                                Gender_Female  Gender_Male  \
# Age                                -0.036248     0.036248
# Height                             -0.016286     0.016286
# Weight                              0.034134    -0.034134
# BMI                                 0.037074    -0.037074
# Gender_Female                       1.000000    -1.000000
# Gender_Male                        -1.000000     1.000000
# PhysicalActivityLevel_1            -0.042265     0.042265
# PhysicalActivityLevel_2            -0.054869     0.054869
# PhysicalActivityLevel_3             0.020051    -0.020051
# PhysicalActivityLevel_4             0.075211    -0.075211
# ObesityCategory_Normal weight      -0.049598     0.049598
# ObesityCategory_Obese               0.004548    -0.004548
# ObesityCategory_Overweight          0.062714    -0.062714
# ObesityCategory_Underweight        -0.018364     0.018364
#
#                                PhysicalActivityLevel_1  \
# Age                                           0.030458
# Height                                       -0.000730
# Weight                                       -0.074387
# BMI                                          -0.062682
# Gender_Female                                -0.042265
# Gender_Male                                   0.042265
# PhysicalActivityLevel_1                       1.000000
# PhysicalActivityLevel_2                      -0.320965
# PhysicalActivityLevel_3                      -0.327868
# PhysicalActivityLevel_4                      -0.331320
# ObesityCategory_Normal weight                 0.030730
# ObesityCategory_Obese                        -0.051592
# ObesityCategory_Overweight                    0.002545
# ObesityCategory_Underweight                   0.012211
#
#                                PhysicalActivityLevel_2  \
# Age                                           0.029113
# Height                                       -0.036791
# Weight                                        0.048142
# BMI                                           0.063622
# Gender_Female                                -0.054869
# Gender_Male                                   0.054869
# PhysicalActivityLevel_1                      -0.320965
# PhysicalActivityLevel_2                       1.000000
# PhysicalActivityLevel_3                      -0.335076
# PhysicalActivityLevel_4                      -0.338604
# ObesityCategory_Normal weight                -0.012658
# ObesityCategory_Obese                         0.057944
# ObesityCategory_Overweight                   -0.029821
# ObesityCategory_Underweight                  -0.008750
#
#                                PhysicalActivityLevel_3  \
# Age                                          -0.089913
# Height                                        0.000001
# Weight                                       -0.036513
# BMI                                          -0.035488
# Gender_Female                                 0.020051
# Gender_Male                                  -0.020051
# PhysicalActivityLevel_1                      -0.327868
# PhysicalActivityLevel_2                      -0.335076
# PhysicalActivityLevel_3                       1.000000
# PhysicalActivityLevel_4                      -0.345886
# ObesityCategory_Normal weight                -0.002873
# ObesityCategory_Obese                        -0.009951
# ObesityCategory_Overweight                   -0.006163
# ObesityCategory_Underweight                   0.023168
#
#                                PhysicalActivityLevel_4  \
# Age                                           0.031146
# Height                                        0.036928
# Weight                                        0.061351
# BMI                                           0.033697
# Gender_Female                                 0.075211
# Gender_Male                                  -0.075211
# PhysicalActivityLevel_1                      -0.331320
# PhysicalActivityLevel_2                      -0.338604
# PhysicalActivityLevel_3                      -0.345886
# PhysicalActivityLevel_4                       1.000000
# ObesityCategory_Normal weight                -0.014596
# ObesityCategory_Obese                         0.003084
# ObesityCategory_Overweight                    0.033010
# ObesityCategory_Underweight                  -0.026323
#
#                                ObesityCategory_Normal weight  \
# Age                                                 0.039223
# Height                                              0.200828
# Weight                                             -0.270202
# BMI                                                -0.357668
# Gender_Female                                      -0.049598
# Gender_Male                                         0.049598
# PhysicalActivityLevel_1                             0.030730
# PhysicalActivityLevel_2                            -0.012658
# PhysicalActivityLevel_3                            -0.002873
# PhysicalActivityLevel_4                            -0.014596
# ObesityCategory_Normal weight                       1.000000
# ObesityCategory_Obese                              -0.373168
# ObesityCategory_Overweight                         -0.496796
# ObesityCategory_Underweight                        -0.313718
#
#                                ObesityCategory_Obese  \
# Age                                        -0.022719
# Height                                     -0.361165
# Weight                                      0.562661
# BMI                                         0.703398
# Gender_Female                               0.004548
# Gender_Male                                -0.004548
# PhysicalActivityLevel_1                    -0.051592
# PhysicalActivityLevel_2                     0.057944
# PhysicalActivityLevel_3                    -0.009951
# PhysicalActivityLevel_4                     0.003084
# ObesityCategory_Normal weight              -0.373168
# ObesityCategory_Obese                       1.000000
# ObesityCategory_Overweight                 -0.314310
# ObesityCategory_Underweight                -0.198481
#
#                                ObesityCategory_Overweight  \
# Age                                             -0.059323
# Height                                          -0.083354
# Weight                                           0.278689
# BMI                                              0.253430
# Gender_Female                                    0.062714
# Gender_Male                                     -0.062714
# PhysicalActivityLevel_1                          0.002545
# PhysicalActivityLevel_2                         -0.029821
# PhysicalActivityLevel_3                         -0.006163
# PhysicalActivityLevel_4                          0.033010
# ObesityCategory_Normal weight                   -0.496796
# ObesityCategory_Obese                           -0.314310
# ObesityCategory_Overweight                       1.000000
# ObesityCategory_Underweight                     -0.264237
#
#                                ObesityCategory_Underweight
# Age                                               0.048666
# Height                                            0.237004
# Weight                                           -0.621993
# BMI                                              -0.626422
# Gender_Female                                    -0.018364
# Gender_Male                                       0.018364
# PhysicalActivityLevel_1                           0.012211
# PhysicalActivityLevel_2                          -0.008750
# PhysicalActivityLevel_3                           0.023168
# PhysicalActivityLevel_4                          -0.026323
# ObesityCategory_Normal weight                    -0.313718
# ObesityCategory_Obese                            -0.198481
# ObesityCategory_Overweight                       -0.264237
# ObesityCategory_Underweight                       1.000000

# %%
correlation_with_BMI = obesity_encoded.corrwith(obesity_encoded['BMI'])

# Display the correlation values
print(correlation_with_BMI)
# Out:
# Age                             -0.059791
# Height                          -0.478429
# Weight                           0.860183
# BMI                              1.000000
# Gender_Female                    0.037074
# Gender_Male                     -0.037074
# PhysicalActivityLevel_1         -0.062682
# PhysicalActivityLevel_2          0.063622
# PhysicalActivityLevel_3         -0.035488
# PhysicalActivityLevel_4          0.033697
# ObesityCategory_Normal weight   -0.357668
# ObesityCategory_Obese            0.703398
# ObesityCategory_Overweight       0.253430
# ObesityCategory_Underweight     -0.626422
# dtype: float64

# %%
df_obesity_reg = obesity_encoded.drop('Gender_Female', axis = 1)
df_obesity_reg.head()
# Out:
#    Age  Height  Weight  BMI  Gender_Male  PhysicalActivityLevel_1  \
# 0   56     173      71   23            1                        0
# 1   69     164      89   33            1                        0
# 2   46     168      72   25            0                        0
# 3   32     168      84   29            1                        0
# 4   60     183      69   20            1                        0
#
#    PhysicalActivityLevel_2  PhysicalActivityLevel_3  PhysicalActivityLevel_4  \
# 0                        0                        0                        1
# 1                        1                        0                        0
# 2                        0                        0                        1
# 3                        0                        1                        0
# 4                        0                        1                        0
#
#    ObesityCategory_Normal weight  ObesityCategory_Obese  \
# 0                              1                      0
# 1                              0                      1
# 2                              0                      0
# 3                              0                      0
# 4                              1                      0
#
#    ObesityCategory_Overweight  ObesityCategory_Underweight
# 0                           0                            0
# 1                           0                            0
# 2                           1                            0
# 3                           1                            0
# 4                           0                            0

# %%
df_obesity_reg.describe()
# Out:
#                Age       Height      Weight          BMI  Gender_Male  \
# count  1000.000000  1000.000000  1000.00000  1000.000000  1000.000000
# mean     49.857000   169.549000    70.68500    24.384000     0.523000
# std      18.114267    10.316202    15.50749     6.204437     0.499721
# min      18.000000   136.000000    26.00000     8.000000     0.000000
# 25%      35.000000   163.000000    61.00000    20.000000     0.000000
# 50%      50.000000   169.000000    71.00000    24.000000     1.000000
# 75%      66.000000   177.000000    81.00000    28.000000     1.000000
# max      79.000000   201.000000   118.00000    50.000000     1.000000
#
#        PhysicalActivityLevel_1  PhysicalActivityLevel_2  \
# count              1000.000000              1000.000000
# mean                  0.239000                 0.247000
# std                   0.426686                 0.431483
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   1.000000                 1.000000
#
#        PhysicalActivityLevel_3  PhysicalActivityLevel_4  \
# count              1000.000000              1000.000000
# mean                  0.255000                 0.259000
# std                   0.436079                 0.438305
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   1.000000                 1.000000
# max                   1.000000                 1.000000
#
#        ObesityCategory_Normal weight  ObesityCategory_Obese  \
# count                    1000.000000            1000.000000
# mean                        0.371000               0.191000
# std                         0.483314               0.393286
# min                         0.000000               0.000000
# 25%                         0.000000               0.000000
# 50%                         0.000000               0.000000
# 75%                         1.000000               0.000000
# max                         1.000000               1.000000
#
#        ObesityCategory_Overweight  ObesityCategory_Underweight
# count                 1000.000000                  1000.000000
# mean                     0.295000                     0.143000
# std                      0.456271                     0.350248
# min                      0.000000                     0.000000
# 25%                      0.000000                     0.000000
# 50%                      0.000000                     0.000000
# 75%                      1.000000                     0.000000
# max                      1.000000                     1.000000

# %%
X = df_obesity_reg.drop('BMI', axis=1)
y = df_obesity_reg['BMI']

# %%
X.shape
# Out:
# (1000, 12)

# %%
y.shape
# Out:
# (1000,)

# %% [markdown]
# Stepwise Selection

# %%
selected_features_stepwise = fun.stepwise_selection(X, y)
selected_features_stepwise
# Out:
# ['Weight', 'Height', 'ObesityCategory_Obese', 'ObesityCategory_Underweight']

# %%
# Re-fit the model using Forward Selection results and display statistics
model_stepwise = sm.OLS(y, X[['Weight', 'Height', 'ObesityCategory_Obese', 'ObesityCategory_Underweight']]).fit()

# Display the model summary which includes similar statistics to what SPSS would provide
model_summary_stepwise = model_stepwise.summary()
print(model_summary_stepwise)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    BMI   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.988
# Method:                 Least Squares   F-statistic:                          2.018e+04
# Date:                Fri, 10 May 2024   Prob (F-statistic):                        0.00
# Time:                        01:45:38   Log-Likelihood:                         -2440.6
# No. Observations:                1000   AIC:                                      4889.
# Df Residuals:                     996   BIC:                                      4909.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Weight                          0.2956      0.010     28.895      0.000       0.276       0.316
# Height                          0.0162      0.004      3.774      0.000       0.008       0.025
# ObesityCategory_Obese           4.5380      0.315     14.399      0.000       3.920       5.156
# ObesityCategory_Underweight    -1.8870      0.368     -5.122      0.000      -2.610      -1.164
# ==============================================================================
# Omnibus:                       40.256   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.139
# Skew:                           0.403   Prob(JB):                     4.77e-12
# Kurtosis:                       3.775   Cond. No.                         856.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Enter Method

# %%
model_enter_summary =fun.enter_selection_method(X, y)
print(model_enter_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BMI   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     5901.
# Date:                Fri, 10 May 2024   Prob (F-statistic):               0.00
# Time:                        01:46:15   Log-Likelihood:                -1191.0
# No. Observations:                1000   AIC:                             2404.
# Df Residuals:                     989   BIC:                             2458.
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            32.5046      0.332     97.918      0.000      31.853      33.156
# Age                               0.0005      0.001      0.369      0.712      -0.002       0.003
# Height                           -0.2842      0.004    -74.062      0.000      -0.292      -0.277
# Weight                            0.3381      0.004     81.581      0.000       0.330       0.346
# Gender_Male                      -0.0087      0.051     -0.170      0.865      -0.109       0.091
# PhysicalActivityLevel_1           8.1564      0.095     86.088      0.000       7.970       8.342
# PhysicalActivityLevel_2           8.1495      0.093     87.975      0.000       7.968       8.331
# PhysicalActivityLevel_3           8.0785      0.094     86.401      0.000       7.895       8.262
# PhysicalActivityLevel_4           8.1201      0.095     85.398      0.000       7.934       8.307
# ObesityCategory_Normal weight     7.7431      0.108     71.512      0.000       7.531       7.956
# ObesityCategory_Obese             8.7530      0.104     84.219      0.000       8.549       8.957
# ObesityCategory_Overweight        7.8170      0.086     91.375      0.000       7.649       7.985
# ObesityCategory_Underweight       8.1913      0.176     46.499      0.000       7.846       8.537
# ==============================================================================
# Omnibus:                      420.135   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4057.680
# Skew:                           1.658   Prob(JB):                         0.00
# Kurtosis:                      12.294   Cond. No.                     1.35e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.99e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
